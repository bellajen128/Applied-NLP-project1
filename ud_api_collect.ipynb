# %%
# collect_ud.py
"""
Collect N unique Urban Dictionary entries whose written_on date is within 2015 (inclusive).
Uses the unofficial UD random endpoint; may require many attempts because `random` samples.
Outputs: ud_2015.csv
"""
import requests
import time
import csv
from datetime import datetime
from dateutil import parser as dateparser
from dateutil.tz import tzutc
from pathlib import Path

# -------- CONFIG --------
OUT = Path("ud_2015.csv")
API_RANDOM = "https://api.urbandictionary.com/v0/random"
HEADERS = {"User-Agent": "Northeastern-SlangPhraser/0.1 (+mailto:you@your.university.edu)"}
RATE_SEC = 1.0          # polite delay (seconds) between requests
TARGET = 5000            # desired number of final entries (change as needed)
MAX_ATTEMPTS = 20000    # safety cap on number of API calls/attempt loops
VERBOSE = True          # set False to reduce console output
# ------------------------

# 2015 inclusive bounds (timezone-aware; UTC)
START = datetime(2015, 1, 1, 0, 0, 0, tzinfo=tzutc())
END   = datetime(2015, 12, 31, 23, 59, 59, tzinfo=tzutc())

def parse_date(dstr):
    """Parse a date string into a timezone-aware datetime in UTC (returns None on failure)."""
    if not dstr:
        return None
    try:
        dt = dateparser.parse(dstr)
    except Exception:
        return None
    if dt is None:
        return None
    # If naive, assume UTC; otherwise normalize to UTC
    if dt.tzinfo is None:
        dt = dt.replace(tzinfo=tzutc())
    else:
        dt = dt.astimezone(tzutc())
    return dt

def normalize_text(s: str) -> str:
    """Normalize text for duplicate detection."""
    if not s:
        return ""
    s = " ".join(s.split())  # collapse whitespace, remove newlines
    return s.lower().strip()

def fetch_random():
    """Call the UD random endpoint and return the 'list' (may be empty)."""
    r = requests.get(API_RANDOM, headers=HEADERS, timeout=15)
    r.raise_for_status()
    return r.json().get("list", [])

def collect(target=TARGET, max_attempts=MAX_ATTEMPTS):
    seen_ids = set()
    seen_texts = set()
    collected = []
    attempts = 0

    print(f"Starting collection for selected year entries (target={target})...")
    while len(collected) < target and attempts < max_attempts:
        attempts += 1
        try:
            items = fetch_random()
        except Exception as e:
            if VERBOSE:
                print(f"[attempt {attempts}] request error: {e} — backing off 5s")
            time.sleep(5)
            continue

        for d in items:
            defid = d.get("defid") or d.get("def_id") or d.get("id") or None
            if not defid:
                # skip malformed entries
                continue
            if defid in seen_ids:
                continue

            # parse and normalize date
            raw_date = d.get("written_on") or d.get("date") or d.get("created_on") or ""
            dt = parse_date(raw_date)
            if not dt:
                # no usable date — skip
                seen_ids.add(defid)
                continue

            # accept only if within year inclusive
            if dt < START or dt > END:
                seen_ids.add(defid)
                continue

            # dedupe by normalized definition text (avoid near-exact duplicates)
            definition_text = d.get("definition") or ""
            norm_def = normalize_text(definition_text)
            if not norm_def:
                seen_ids.add(defid)
                continue
            if norm_def in seen_texts:
                seen_ids.add(defid)
                continue

            # build record (safe-get other fields)
            record = {
                "defid": defid,
                "word": d.get("word",""),
                "definition": definition_text.replace("\n"," ").strip(),
                "example": (d.get("example") or "").replace("\n"," ").strip(),
                "written_on": raw_date
            }
            collected.append(record)
            seen_ids.add(defid)
            seen_texts.add(norm_def)

            if len(collected) >= target:
                break

        # occasional status print
        if VERBOSE and attempts % 50 == 0:
            print(f"Attempt {attempts} — collected {len(collected)} valid selected year items so far")

        time.sleep(RATE_SEC)

    if VERBOSE:
        print(f"Finished: attempts={attempts}, collected={len(collected)} (target={target})")

    # sort by parsed date (descending, newest first)
    collected.sort(key=lambda x: parse_date(x["written_on"]) if x["written_on"] else datetime(1970,1,1,tzinfo=tzutc()), reverse=True)

    # write CSV (even if fewer than target)
    cols = ["defid","word","definition","example","written_on"]
    with OUT.open("w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=cols)
        writer.writeheader()
        for row in collected[:target]:
            writer.writerow({k: row.get(k,"") for k in cols})

    print(f"Wrote {min(len(collected), target)} rows to {OUT.resolve()}")
    return OUT

if __name__ == "__main__":
    collect()
# Out:
# Starting collection for selected year entries (target=5000)...
# Attempt 50 — collected 5 valid selected year items so far
# Attempt 100 — collected 9 valid selected year items so far
# Attempt 150 — collected 15 valid selected year items so far
# Attempt 200 — collected 21 valid selected year items so far
# Attempt 250 — collected 25 valid selected year items so far
# Attempt 300 — collected 32 valid selected year items so far
# Attempt 350 — collected 40 valid selected year items so far
# Attempt 400 — collected 45 valid selected year items so far
# Attempt 450 — collected 50 valid selected year items so far
# Attempt 500 — collected 59 valid selected year items so far
# Attempt 550 — collected 68 valid selected year items so far
# Attempt 600 — collected 78 valid selected year items so far
# Attempt 650 — collected 88 valid selected year items so far
# Attempt 700 — collected 102 valid selected year items so far
# Attempt 750 — collected 107 valid selected year items so far
# Attempt 800 — collected 114 valid selected year items so far
# Attempt 850 — collected 119 valid selected year items so far
# Attempt 900 — collected 127 valid selected year items so far
# Attempt 950 — collected 134 valid selected year items so far
# Attempt 1000 — collected 139 valid selected year items so far
# Attempt 1050 — collected 149 valid selected year items so far
# Attempt 1100 — collected 159 valid selected year items so far
# Attempt 1150 — collected 166 valid selected year items so far
# Attempt 1200 — collected 175 valid selected year items so far
# Attempt 1250 — collected 178 valid selected year items so far
# Attempt 1300 — collected 187 valid selected year items so far
# Attempt 1350 — collected 196 valid selected year items so far
# Attempt 1400 — collected 205 valid selected year items so far
# Attempt 1450 — collected 215 valid selected year items so far
# Attempt 1500 — collected 223 valid selected year items so far
# Attempt 1550 — collected 235 valid selected year items so far
# Attempt 1600 — collected 242 valid selected year items so far
# Attempt 1650 — collected 252 valid selected year items so far
# Attempt 1700 — collected 256 valid selected year items so far
# Attempt 1750 — collected 264 valid selected year items so far
# Attempt 1800 — collected 273 valid selected year items so far
# Attempt 1850 — collected 282 valid selected year items so far
# Attempt 1900 — collected 294 valid selected year items so far
# Attempt 1950 — collected 300 valid selected year items so far
# Attempt 2000 — collected 308 valid selected year items so far
# Attempt 2050 — collected 317 valid selected year items so far
# Attempt 2100 — collected 325 valid selected year items so far
# Attempt 2150 — collected 335 valid selected year items so far
# Attempt 2200 — collected 345 valid selected year items so far
# Attempt 2250 — collected 351 valid selected year items so far
# Attempt 2300 — collected 355 valid selected year items so far
# Attempt 2350 — collected 363 valid selected year items so far
# Attempt 2400 — collected 367 valid selected year items so far
# Attempt 2450 — collected 378 valid selected year items so far
# Attempt 2500 — collected 390 valid selected year items so far
# Attempt 2550 — collected 397 valid selected year items so far
# Attempt 2600 — collected 406 valid selected year items so far
# Attempt 2650 — collected 410 valid selected year items so far
# Attempt 2700 — collected 418 valid selected year items so far
# Attempt 2750 — collected 426 valid selected year items so far
# Attempt 2800 — collected 434 valid selected year items so far
# Attempt 2850 — collected 438 valid selected year items so far
# Attempt 2900 — collected 445 valid selected year items so far
# Attempt 2950 — collected 453 valid selected year items so far
# Attempt 3000 — collected 460 valid selected year items so far
# Attempt 3050 — collected 465 valid selected year items so far
# Attempt 3100 — collected 475 valid selected year items so far
# Attempt 3150 — collected 481 valid selected year items so far
# Attempt 3200 — collected 488 valid selected year items so far
# Attempt 3250 — collected 494 valid selected year items so far
# Attempt 3300 — collected 502 valid selected year items so far
# Attempt 3350 — collected 508 valid selected year items so far
# Attempt 3400 — collected 517 valid selected year items so far
# Attempt 3450 — collected 527 valid selected year items so far
# Attempt 3500 — collected 533 valid selected year items so far
# Attempt 3550 — collected 538 valid selected year items so far
# Attempt 3600 — collected 544 valid selected year items so far
# Attempt 3650 — collected 550 valid selected year items so far
# Attempt 3700 — collected 557 valid selected year items so far
# Attempt 3750 — collected 568 valid selected year items so far
# Attempt 3800 — collected 574 valid selected year items so far
# Attempt 3850 — collected 580 valid selected year items so far
# Attempt 3900 — collected 588 valid selected year items so far
# Attempt 3950 — collected 598 valid selected year items so far
# Attempt 4000 — collected 612 valid selected year items so far
# Attempt 4050 — collected 627 valid selected year items so far
# Attempt 4100 — collected 634 valid selected year items so far
# Attempt 4150 — collected 640 valid selected year items so far
# Attempt 4200 — collected 648 valid selected year items so far
# Attempt 4250 — collected 657 valid selected year items so far
# Attempt 4300 — collected 668 valid selected year items so far
# Attempt 4350 — collected 675 valid selected year items so far
# Attempt 4400 — collected 686 valid selected year items so far
# Attempt 4450 — collected 694 valid selected year items so far
# Attempt 4500 — collected 706 valid selected year items so far
# Attempt 4550 — collected 715 valid selected year items so far
# Attempt 4600 — collected 721 valid selected year items so far
# Attempt 4650 — collected 725 valid selected year items so far
# Attempt 4700 — collected 731 valid selected year items so far
# Attempt 4750 — collected 747 valid selected year items so far
# Attempt 4800 — collected 753 valid selected year items so far
# Attempt 4850 — collected 762 valid selected year items so far
# Attempt 4900 — collected 771 valid selected year items so far
# Attempt 4950 — collected 776 valid selected year items so far
# Attempt 5000 — collected 784 valid selected year items so far
# Attempt 5050 — collected 789 valid selected year items so far
# Attempt 5100 — collected 799 valid selected year items so far
# Attempt 5150 — collected 803 valid selected year items so far
# Attempt 5200 — collected 813 valid selected year items so far
# Attempt 5250 — collected 818 valid selected year items so far
# Attempt 5300 — collected 826 valid selected year items so far
# Attempt 5350 — collected 836 valid selected year items so far
# Attempt 5400 — collected 848 valid selected year items so far
# Attempt 5450 — collected 857 valid selected year items so far
# Attempt 5500 — collected 868 valid selected year items so far
# Attempt 5550 — collected 874 valid selected year items so far
# Attempt 5600 — collected 884 valid selected year items so far
# Attempt 5650 — collected 892 valid selected year items so far
# Attempt 5700 — collected 900 valid selected year items so far
# Attempt 5750 — collected 906 valid selected year items so far
# Attempt 5800 — collected 914 valid selected year items so far
# Attempt 5850 — collected 922 valid selected year items so far
# Attempt 5900 — collected 925 valid selected year items so far
# Attempt 5950 — collected 932 valid selected year items so far
# Attempt 6000 — collected 938 valid selected year items so far
# Attempt 6050 — collected 943 valid selected year items so far
# Attempt 6100 — collected 945 valid selected year items so far
# Attempt 6150 — collected 951 valid selected year items so far
# Attempt 6200 — collected 961 valid selected year items so far
# Attempt 6250 — collected 968 valid selected year items so far
# Attempt 6300 — collected 975 valid selected year items so far
# Attempt 6350 — collected 980 valid selected year items so far
# Attempt 6400 — collected 991 valid selected year items so far
# Attempt 6450 — collected 993 valid selected year items so far
# Attempt 6500 — collected 1000 valid selected year items so far
# Attempt 6550 — collected 1011 valid selected year items so far
# Attempt 6600 — collected 1019 valid selected year items so far
# Attempt 6650 — collected 1027 valid selected year items so far
# Attempt 6700 — collected 1032 valid selected year items so far
# Attempt 6750 — collected 1040 valid selected year items so far
# Attempt 6800 — collected 1046 valid selected year items so far
# Attempt 6850 — collected 1054 valid selected year items so far
# Attempt 6900 — collected 1058 valid selected year items so far
# Attempt 6950 — collected 1064 valid selected year items so far
# Attempt 7000 — collected 1070 valid selected year items so far
# Attempt 7050 — collected 1080 valid selected year items so far
# Attempt 7100 — collected 1087 valid selected year items so far
# Attempt 7150 — collected 1094 valid selected year items so far
# Attempt 7200 — collected 1105 valid selected year items so far
# Attempt 7250 — collected 1114 valid selected year items so far
# Attempt 7300 — collected 1120 valid selected year items so far
# Attempt 7350 — collected 1124 valid selected year items so far
# Attempt 7400 — collected 1132 valid selected year items so far
# Attempt 7450 — collected 1137 valid selected year items so far
# Attempt 7500 — collected 1142 valid selected year items so far
# Attempt 7550 — collected 1151 valid selected year items so far
# Attempt 7600 — collected 1160 valid selected year items so far
# Attempt 7650 — collected 1173 valid selected year items so far
# Attempt 7700 — collected 1179 valid selected year items so far
# Attempt 7750 — collected 1189 valid selected year items so far
# Attempt 7800 — collected 1194 valid selected year items so far
# Attempt 7850 — collected 1200 valid selected year items so far
# Attempt 7900 — collected 1211 valid selected year items so far
# Attempt 7950 — collected 1219 valid selected year items so far
# Attempt 8000 — collected 1223 valid selected year items so far
# Attempt 8050 — collected 1229 valid selected year items so far
# Attempt 8100 — collected 1236 valid selected year items so far
# Attempt 8150 — collected 1244 valid selected year items so far
# Attempt 8200 — collected 1255 valid selected year items so far
# Attempt 8250 — collected 1264 valid selected year items so far
# Attempt 8300 — collected 1273 valid selected year items so far
# Attempt 8350 — collected 1281 valid selected year items so far
# Attempt 8400 — collected 1288 valid selected year items so far
# Attempt 8450 — collected 1295 valid selected year items so far
# Attempt 8500 — collected 1306 valid selected year items so far
# Attempt 8550 — collected 1311 valid selected year items so far
# Attempt 8600 — collected 1322 valid selected year items so far
# Attempt 8650 — collected 1326 valid selected year items so far
# Attempt 8700 — collected 1334 valid selected year items so far
# Attempt 8750 — collected 1338 valid selected year items so far
# Attempt 8800 — collected 1351 valid selected year items so far
# Attempt 8850 — collected 1358 valid selected year items so far
# Attempt 8900 — collected 1366 valid selected year items so far
# Attempt 8950 — collected 1372 valid selected year items so far
# Attempt 9000 — collected 1385 valid selected year items so far
# Attempt 9050 — collected 1387 valid selected year items so far
# Attempt 9100 — collected 1397 valid selected year items so far
# Attempt 9150 — collected 1400 valid selected year items so far
# Attempt 9200 — collected 1411 valid selected year items so far
# Attempt 9250 — collected 1417 valid selected year items so far
# Attempt 9300 — collected 1427 valid selected year items so far
# Attempt 9350 — collected 1438 valid selected year items so far
# Attempt 9400 — collected 1445 valid selected year items so far
# Attempt 9450 — collected 1451 valid selected year items so far
# Attempt 9500 — collected 1463 valid selected year items so far
# Attempt 9550 — collected 1471 valid selected year items so far
# Attempt 9600 — collected 1477 valid selected year items so far
# Attempt 9650 — collected 1485 valid selected year items so far
# Attempt 9700 — collected 1493 valid selected year items so far
# Attempt 9750 — collected 1500 valid selected year items so far
# Attempt 9800 — collected 1504 valid selected year items so far
# Attempt 9850 — collected 1514 valid selected year items so far
# Attempt 9900 — collected 1520 valid selected year items so far
# Attempt 9950 — collected 1527 valid selected year items so far
# Attempt 10000 — collected 1533 valid selected year items so far
# Attempt 10050 — collected 1542 valid selected year items so far
# Attempt 10100 — collected 1546 valid selected year items so far
# Attempt 10150 — collected 1553 valid selected year items so far
# Attempt 10200 — collected 1564 valid selected year items so far
# Attempt 10250 — collected 1569 valid selected year items so far
# Attempt 10300 — collected 1575 valid selected year items so far
# Attempt 10350 — collected 1582 valid selected year items so far
# Attempt 10400 — collected 1587 valid selected year items so far
# Attempt 10450 — collected 1596 valid selected year items so far
# Attempt 10500 — collected 1599 valid selected year items so far
# Attempt 10550 — collected 1607 valid selected year items so far
# Attempt 10600 — collected 1617 valid selected year items so far
# Attempt 10650 — collected 1626 valid selected year items so far
# Attempt 10700 — collected 1636 valid selected year items so far
# Attempt 10750 — collected 1649 valid selected year items so far
# Attempt 10800 — collected 1655 valid selected year items so far
# Attempt 10850 — collected 1662 valid selected year items so far
# Attempt 10900 — collected 1675 valid selected year items so far
# Attempt 10950 — collected 1680 valid selected year items so far
# Attempt 11000 — collected 1686 valid selected year items so far
# Attempt 11050 — collected 1692 valid selected year items so far
# Attempt 11100 — collected 1699 valid selected year items so far
# Attempt 11150 — collected 1708 valid selected year items so far
# Attempt 11200 — collected 1719 valid selected year items so far
# Attempt 11250 — collected 1725 valid selected year items so far
# Attempt 11300 — collected 1734 valid selected year items so far
# Attempt 11350 — collected 1743 valid selected year items so far
# Attempt 11400 — collected 1751 valid selected year items so far
# Attempt 11450 — collected 1754 valid selected year items so far
# Attempt 11500 — collected 1759 valid selected year items so far
# Attempt 11550 — collected 1769 valid selected year items so far
# Attempt 11600 — collected 1780 valid selected year items so far
# Attempt 11650 — collected 1792 valid selected year items so far
# Attempt 11700 — collected 1805 valid selected year items so far
# Attempt 11750 — collected 1811 valid selected year items so far
# Attempt 11800 — collected 1822 valid selected year items so far
# Attempt 11850 — collected 1829 valid selected year items so far
# Attempt 11900 — collected 1838 valid selected year items so far
# Attempt 11950 — collected 1846 valid selected year items so far
# Attempt 12000 — collected 1854 valid selected year items so far
# Attempt 12050 — collected 1862 valid selected year items so far
# Attempt 12100 — collected 1867 valid selected year items so far
# Attempt 12150 — collected 1874 valid selected year items so far
# Attempt 12200 — collected 1877 valid selected year items so far
# Attempt 12250 — collected 1883 valid selected year items so far
# Attempt 12300 — collected 1891 valid selected year items so far
# Attempt 12350 — collected 1897 valid selected year items so far
# Attempt 12400 — collected 1905 valid selected year items so far
# Attempt 12450 — collected 1911 valid selected year items so far
# Attempt 12500 — collected 1917 valid selected year items so far
# Attempt 12550 — collected 1928 valid selected year items so far
# Attempt 12600 — collected 1935 valid selected year items so far
# Attempt 12650 — collected 1945 valid selected year items so far
# Attempt 12700 — collected 1952 valid selected year items so far
# Attempt 12750 — collected 1962 valid selected year items so far
# Attempt 12800 — collected 1965 valid selected year items so far
# Attempt 12850 — collected 1971 valid selected year items so far
# Attempt 12900 — collected 1977 valid selected year items so far
# Attempt 12950 — collected 1987 valid selected year items so far
# Attempt 13000 — collected 2000 valid selected year items so far
# Attempt 13050 — collected 2010 valid selected year items so far
# Attempt 13100 — collected 2017 valid selected year items so far
# Attempt 13150 — collected 2029 valid selected year items so far
# Attempt 13200 — collected 2035 valid selected year items so far
# Attempt 13250 — collected 2040 valid selected year items so far
# Attempt 13300 — collected 2052 valid selected year items so far
# Attempt 13350 — collected 2061 valid selected year items so far
# Attempt 13400 — collected 2074 valid selected year items so far
# Attempt 13450 — collected 2083 valid selected year items so far
# Attempt 13500 — collected 2091 valid selected year items so far
# Attempt 13550 — collected 2095 valid selected year items so far
# Attempt 13600 — collected 2104 valid selected year items so far
# Attempt 13650 — collected 2117 valid selected year items so far
# Attempt 13700 — collected 2125 valid selected year items so far
# Attempt 13750 — collected 2129 valid selected year items so far
# Attempt 13800 — collected 2135 valid selected year items so far
# Attempt 13850 — collected 2141 valid selected year items so far
# Attempt 13900 — collected 2150 valid selected year items so far
# Attempt 13950 — collected 2158 valid selected year items so far
# Attempt 14000 — collected 2163 valid selected year items so far
# Attempt 14050 — collected 2172 valid selected year items so far
# Attempt 14100 — collected 2178 valid selected year items so far
# Attempt 14150 — collected 2186 valid selected year items so far
# Attempt 14200 — collected 2192 valid selected year items so far
# Attempt 14250 — collected 2198 valid selected year items so far
# Attempt 14300 — collected 2208 valid selected year items so far
# Attempt 14350 — collected 2214 valid selected year items so far
# Attempt 14400 — collected 2223 valid selected year items so far
# Attempt 14450 — collected 2234 valid selected year items so far
# Attempt 14500 — collected 2236 valid selected year items so far
# Attempt 14550 — collected 2243 valid selected year items so far
# Attempt 14600 — collected 2258 valid selected year items so far
# Attempt 14650 — collected 2261 valid selected year items so far
# Attempt 14700 — collected 2266 valid selected year items so far
# Attempt 14750 — collected 2280 valid selected year items so far
# Attempt 14800 — collected 2288 valid selected year items so far
# Attempt 14850 — collected 2293 valid selected year items so far
# Attempt 14900 — collected 2301 valid selected year items so far
# Attempt 14950 — collected 2309 valid selected year items so far
# Attempt 15000 — collected 2316 valid selected year items so far
# Attempt 15050 — collected 2325 valid selected year items so far
# Attempt 15100 — collected 2333 valid selected year items so far
# Attempt 15150 — collected 2342 valid selected year items so far
# Attempt 15200 — collected 2354 valid selected year items so far
# Attempt 15250 — collected 2363 valid selected year items so far
# Attempt 15300 — collected 2369 valid selected year items so far
# Attempt 15350 — collected 2375 valid selected year items so far
# Attempt 15400 — collected 2386 valid selected year items so far
# Attempt 15450 — collected 2392 valid selected year items so far
# Attempt 15500 — collected 2396 valid selected year items so far
# Attempt 15550 — collected 2402 valid selected year items so far
# Attempt 15600 — collected 2408 valid selected year items so far
# Attempt 15650 — collected 2416 valid selected year items so far
# Attempt 15700 — collected 2422 valid selected year items so far
# Attempt 15750 — collected 2429 valid selected year items so far
# Attempt 15800 — collected 2444 valid selected year items so far
# Attempt 15850 — collected 2449 valid selected year items so far
# Attempt 15900 — collected 2458 valid selected year items so far
# Attempt 15950 — collected 2467 valid selected year items so far
# Attempt 16000 — collected 2473 valid selected year items so far
# Attempt 16050 — collected 2479 valid selected year items so far
# Attempt 16100 — collected 2490 valid selected year items so far
# Attempt 16150 — collected 2501 valid selected year items so far
# Attempt 16200 — collected 2508 valid selected year items so far
# Attempt 16250 — collected 2515 valid selected year items so far
# Attempt 16300 — collected 2521 valid selected year items so far
# Attempt 16350 — collected 2530 valid selected year items so far
# Attempt 16400 — collected 2538 valid selected year items so far
# Attempt 16450 — collected 2552 valid selected year items so far
# Attempt 16500 — collected 2559 valid selected year items so far
# Attempt 16550 — collected 2567 valid selected year items so far
# Attempt 16600 — collected 2572 valid selected year items so far
# Attempt 16650 — collected 2578 valid selected year items so far
# Attempt 16700 — collected 2584 valid selected year items so far
